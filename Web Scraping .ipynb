# %% [markdown]
# </h2> Data Preparation for Analysis and Visulization </h2>

# %%
import requests
import lxml.html as lh
import pandas as pd

# %%
WHO_url = 'https://www.worldometers.info/coronavirus/'
page = requests.get(WHO_url)
doc = lh.fromstring(page.content)
tr_elements= doc.xpath('//tr')
[len(T) for T in tr_elements [:12]]
# Out:
# [22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22, 22]

# %%
tr_elements = doc.xpath('//tr')
col = []
i = 0
for t in tr_elements [0]:
    i+=1
    name=t.text_content()
    print ("%d:%s" % (i,name))
    col.append((name, []))
# Out:
# 1:#
# 2:Country,Other
# 3:TotalCases
# 4:NewCases
# 5:TotalDeaths
# 6:NewDeaths
# 7:TotalRecovered
# 8:NewRecovered
# 9:ActiveCases
# 10:Serious,Critical
# 11:Tot Cases/1M pop
# 12:Deaths/1M pop
# 13:TotalTests
# 14:Tests/
# 1M pop
#
# 15:Population
# 16:Continent
# 17:1 Caseevery X ppl
# 18:1 Deathevery X ppl
# 19:1 Testevery X ppl
# 20:New Cases/1M pop
# 21:New Deaths/1M pop
# 22:Active Cases/1M pop

# %%
for j in range(1,len(tr_elements)): # Because header is the first row, data would be store in the subsequent rows.
    T = tr_elements[j] #T is j'th row
    
    if len(T)!=22: #if row is not size 3, //tr data is not from the table.
        break
        
    i = 0 #i is the index of the first column
    
    for t in T.iterchildren(): #iterate through each element of the row
        data=t.text_content()
            
        col[i][1].append(data) #append the data to the empty list of the i'th column
            
        i+=1 #increment i for the next column

# %%
[len(C) for (title,C) in col]
# Out:
# [740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740,
#  740]

# %%
Dict = {title:column for (title,column) in col}
df = pd.DataFrame(Dict)

# %%
df.head()
# Out:
#   #      Country,Other   TotalCases NewCases TotalDeaths NewDeaths  \
# 0    \nNorth America\n  104,856,267  +16,214   1,485,565       +23
# 1             \nAsia\n  160,635,629  +33,403   1,438,207       +32
# 2    \nSouth America\n   59,308,404     +858   1,303,908        +1
# 3           \nEurope\n  201,994,637            1,853,073
# 4          \nOceania\n    9,632,882  +28,256      13,812       +32
#
#   TotalRecovered NewRecovered ActiveCases Serious,Critical  ... TotalTests  \
# 0     98,414,284       +5,723   4,956,418            8,509  ...
# 1    154,970,504      +39,718   4,226,918           10,375  ...
# 2     56,172,412       +7,044   1,832,084           10,349  ...
# 3    193,335,536      +70,747   6,806,028            5,865  ...
# 4      9,274,375       +3,341     344,695              140  ...
#
#   Tests/\n1M pop\n Population          Continent 1 Caseevery X ppl  \
# 0                                  North America                \n
# 1                                           Asia                \n
# 2                                  South America                \n
# 3                                         Europe                \n
# 4                              Australia/Oceania                \n
#
#   1 Deathevery X ppl 1 Testevery X ppl New Cases/1M pop New Deaths/1M pop  \
# 0
# 1
# 2
# 3
# 4
#
#   Active Cases/1M pop
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 22 columns]

# %%
df = df.replace(',', '', regex=True)
df = df.replace('\+', '', regex=True)

# %%
df.head()
# Out:
#   TotalCases NewCases TotalDeaths NewDeaths TotalRecovered NewRecovered  \
# 0  104856267    16214     1485565        23       98414284         5723
# 1  160635629    33403     1438207        32      154970504        39718
# 2   59308404      858     1303908         1       56172412         7044
# 3  201994637              1853073                193335536        70747
# 4    9632882    28256       13812        32        9274375         3341
#
#   ActiveCases Serious,Critical
# 0     4956418             8509
# 1     4226918            10375
# 2     1832084            10349
# 3     6806028             5865
# 4      344695              140

# %%
Dict = {title:column for (title,column) in col}
df = pd.DataFrame(Dict)

# %%
df.head()
# Out:
#   #      Country,Other   TotalCases NewCases TotalDeaths NewDeaths  \
# 0    \nNorth America\n  104,856,267  +16,214   1,485,565       +23
# 1             \nAsia\n  160,635,629  +33,403   1,438,207       +32
# 2    \nSouth America\n   59,308,404     +858   1,303,908        +1
# 3           \nEurope\n  201,994,637            1,853,073
# 4          \nOceania\n    9,632,882  +28,256      13,812       +32
#
#   TotalRecovered NewRecovered ActiveCases Serious,Critical  ... TotalTests  \
# 0     98,414,284       +5,723   4,956,418            8,509  ...
# 1    154,970,504      +39,718   4,226,918           10,375  ...
# 2     56,172,412       +7,044   1,832,084           10,349  ...
# 3    193,335,536      +70,747   6,806,028            5,865  ...
# 4      9,274,375       +3,341     344,695              140  ...
#
#   Tests/\n1M pop\n Population          Continent 1 Caseevery X ppl  \
# 0                                  North America                \n
# 1                                           Asia                \n
# 2                                  South America                \n
# 3                                         Europe                \n
# 4                              Australia/Oceania                \n
#
#   1 Deathevery X ppl 1 Testevery X ppl New Cases/1M pop New Deaths/1M pop  \
# 0
# 1
# 2
# 3
# 4
#
#   Active Cases/1M pop
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 22 columns]

# %%
df = df.replace(',', '', regex=True)

# %%
df.head()
# Out:
#   #      Country,Other TotalCases NewCases TotalDeaths NewDeaths  \
# 0    \nNorth America\n  104856267   +16214     1485565       +23
# 1             \nAsia\n  160635629   +33403     1438207       +32
# 2    \nSouth America\n   59308404     +858     1303908        +1
# 3           \nEurope\n  201994637              1853073
# 4          \nOceania\n    9632882   +28256       13812       +32
#
#   TotalRecovered NewRecovered ActiveCases Serious,Critical  ... TotalTests  \
# 0       98414284        +5723     4956418             8509  ...
# 1      154970504       +39718     4226918            10375  ...
# 2       56172412        +7044     1832084            10349  ...
# 3      193335536       +70747     6806028             5865  ...
# 4        9274375        +3341      344695              140  ...
#
#   Tests/\n1M pop\n Population          Continent 1 Caseevery X ppl  \
# 0                                  North America                \n
# 1                                           Asia                \n
# 2                                  South America                \n
# 3                                         Europe                \n
# 4                              Australia/Oceania                \n
#
#   1 Deathevery X ppl 1 Testevery X ppl New Cases/1M pop New Deaths/1M pop  \
# 0
# 1
# 2
# 3
# 4
#
#   Active Cases/1M pop
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 22 columns]

# %%
df = df.replace('\+', '', regex=True)

# %%
df.head()
# Out:
#   #      Country,Other TotalCases NewCases TotalDeaths NewDeaths  \
# 0    \nNorth America\n  104856267    16214     1485565        23
# 1             \nAsia\n  160635629    33403     1438207        32
# 2    \nSouth America\n   59308404      858     1303908         1
# 3           \nEurope\n  201994637              1853073
# 4          \nOceania\n    9632882    28256       13812        32
#
#   TotalRecovered NewRecovered ActiveCases Serious,Critical  ... TotalTests  \
# 0       98414284         5723     4956418             8509  ...
# 1      154970504        39718     4226918            10375  ...
# 2       56172412         7044     1832084            10349  ...
# 3      193335536        70747     6806028             5865  ...
# 4        9274375         3341      344695              140  ...
#
#   Tests/\n1M pop\n Population          Continent 1 Caseevery X ppl  \
# 0                                  North America                \n
# 1                                           Asia                \n
# 2                                  South America                \n
# 3                                         Europe                \n
# 4                              Australia/Oceania                \n
#
#   1 Deathevery X ppl 1 Testevery X ppl New Cases/1M pop New Deaths/1M pop  \
# 0
# 1
# 2
# 3
# 4
#
#   Active Cases/1M pop
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 22 columns]

# %%
df1 =df.drop(columns = ['NewCases','NewDeaths','NewRecovered'])
df1.head()
# Out:
#   #      Country,Other TotalCases TotalDeaths TotalRecovered ActiveCases  \
# 0    \nNorth America\n  104856267     1485565       98414284     4956418
# 1             \nAsia\n  160635629     1438207      154970504     4226918
# 2    \nSouth America\n   59308404     1303908       56172412     1832084
# 3           \nEurope\n  201994637     1853073      193335536     6806028
# 4          \nOceania\n    9632882       13812        9274375      344695
#
#   Serious,Critical Tot Cases/1M pop Deaths/1M pop TotalTests Tests/\n1M pop\n  \
# 0             8509
# 1            10375
# 2            10349
# 3             5865
# 4              140
#
#   Population          Continent 1 Caseevery X ppl 1 Deathevery X ppl  \
# 0                 North America                \n
# 1                          Asia                \n
# 2                 South America                \n
# 3                        Europe                \n
# 4             Australia/Oceania                \n
#
#   1 Testevery X ppl New Cases/1M pop New Deaths/1M pop Active Cases/1M pop
# 0
# 1
# 2
# 3
# 4

# %%
df.head (224)
# Out:
#        #          Country,Other TotalCases NewCases TotalDeaths NewDeaths  \
# 0             \nNorth America\n  104856267    16214     1485565        23
# 1                      \nAsia\n  160635629    33403     1438207        32
# 2             \nSouth America\n   59308404      858     1303908         1
# 3                    \nEurope\n  201994637              1853073
# 4                   \nOceania\n    9632882    28256       13812        32
# ..   ...                    ...        ...      ...         ...       ...
# 219  212              St. Barth       4630                   6
# 220  213               Anguilla       3411                   9
# 221  214               Kiribati       3236                  13
# 222  215  Saint Pierre Miquelon       2767                   1
# 223  216       Falkland Islands       1807
#
#     TotalRecovered NewRecovered ActiveCases Serious,Critical  ... TotalTests  \
# 0         98414284         5723     4956418             8509  ...
# 1        154970504        39718     4226918            10375  ...
# 2         56172412         7044     1832084            10349  ...
# 3        193335536        70747     6806028             5865  ...
# 4          9274375         3341      344695              140  ...
# ..             ...          ...         ...              ...  ...        ...
# 219            N/A          N/A         N/A                   ...      78646
# 220           3376                       26                4  ...      51382
# 221           2665                      558                3  ...
# 222           2449                      317                1  ...      24026
# 223            N/A          N/A         N/A                   ...       8632
#
#     Tests/\n1M pop\n Population          Continent 1 Caseevery X ppl  \
# 0                                    North America                \n
# 1                                             Asia                \n
# 2                                    South America                \n
# 3                                           Europe                \n
# 4                                Australia/Oceania                \n
# ..               ...        ...                ...               ...
# 219          7914461      9937       North America                 2
# 220          3365339     15268       North America                 4
# 221                     123072   Australia/Oceania                38
# 222          4187173      5738       North America                 2
# 223          2345652      3680       South America                 2
#
#     1 Deathevery X ppl 1 Testevery X ppl New Cases/1M pop New Deaths/1M pop  \
# 0
# 1
# 2
# 3
# 4
# ..                 ...               ...              ...               ...
# 219               1656                 0
# 220               1696                 0
# 221               9467
# 222               5738                 0
# 223                                    0
#
#     Active Cases/1M pop
# 0
# 1
# 2
# 3
# 4
# ..                  ...
# 219              418839
# 220                1703
# 221                4534
# 222               55246
# 223              457337
#
# [224 rows x 22 columns]
